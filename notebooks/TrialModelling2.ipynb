# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from utils import automated_pipeline

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, AdaBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# %%
file_raw = r'E:\airta drafts\PREDIKSI KADAR HB\data\raw\erm_hd.xlsx'
df_raw = pd.read_excel(file_raw)

df = automated_pipeline(df_raw)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643 entries, 0 to 642
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_pasien        643 non-null    int64
#  1   tgl_pemeriksaan  643 non-null    datetime64[ns]
#  2   usia             643 non-null    Int64
#  3   jk               643 non-null    Int64
#  4   eritrosit        643 non-null    float64
#  5   hematokrit       643 non-null    float64
#  6   MCHC             643 non-null    float64
#  7   MCH              643 non-null    float64
#  8   MCV              643 non-null    float64
#  9   hemoglobin       643 non-null    float64
#  10  leukosit         643 non-null    Int64
#  11  trombosit        643 non-null    Int64
#  12  epo              643 non-null    Int64
# dtypes: Int64(5), datetime64[ns](1), float64(6), int64(1)
# memory usage: 68.6 KB

# %%
df = df.sort_values(by=['tgl_pemeriksaan', 'id_pasien']).reset_index(drop=True)

#LAG FEATURE untuk TSCV
df['hb_now'] = df.groupby('id_pasien')['hemoglobin'].shift(1)
df = df.dropna(subset=['hb_now']).reset_index(drop=True)

#MENENTUKAN FITUR X DAN TARGET Y
X = df.drop(columns=['id_pasien', 'tgl_pemeriksaan', 'hemoglobin', 'hematokrit', 'eritrosit'])
y = df['hemoglobin']

#SPLIT 80:20 BERDASARKAN KRONOLOGIS
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.2, 
    shuffle=False
)

print(f"Total baris data: {len(df)}")
print(f"Jumlah Data Latih (80%): {len(X_train)}")
print(f"Jumlah Data Uji (20%): {len(X_test)}")
print("-" * 30)
print("Fitur yang digunakan (X):", X.columns.tolist())
# Out:
# Total baris data: 571
# Jumlah Data Latih (80%): 456
# Jumlah Data Uji (20%): 115
# ------------------------------
# Fitur yang digunakan (X): ['usia', 'jk', 'MCHC', 'MCH', 'MCV', 'leukosit', 'trombosit', 'epo', 'hb_now']

# %%
# Tabel untuk verifikasi lag feature
lag_table = df[
    ['id_pasien', 'tgl_pemeriksaan', 'hb_now', 'hemoglobin']
].sort_values(by=['id_pasien', 'tgl_pemeriksaan'])

print(lag_table.head(20))
# Out:
#      id_pasien tgl_pemeriksaan    hb_now  hemoglobin
# 28           1      2025-04-01  8.600000    8.100000
# 90           1      2025-05-01  8.100000    8.300000
# 151          1      2025-06-01  8.300000    7.900000
# 213          1      2025-07-01  7.900000    7.500000
# 267          1      2025-08-01  7.500000    7.900000
# 320          1      2025-09-01  7.900000    9.500000
# 372          1      2025-10-01  9.500000    9.100000
# 424          1      2025-11-01  9.100000    8.700000
# 475          1      2025-12-01  8.700000    8.600000
# 0            2      2025-03-01  7.900000    8.300000
# 29           2      2025-04-01  8.300000    7.700000
# 91           2      2025-05-01  7.700000    7.800000
# 152          2      2025-06-01  7.800000    7.900000
# 214          2      2025-07-01  7.900000    7.200000
# 268          2      2025-08-01  7.200000    8.000000
# 321          2      2025-09-01  8.000000    7.833333
# 373          2      2025-10-01  7.833333    8.000000
# 425          2      2025-11-01  8.000000    8.600000
# 476          2      2025-12-01  8.600000    8.900000
# 30           3      2025-04-01  9.200000    9.000000

# %%
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit(n_splits=5)

# Cek bagaimana TSCV membagi data X_train kamu
print(f"Total baris di X_train: {len(X_train)}")
print("-" * 30)

for i, (train_index, val_index) in enumerate(tscv.split(X_train)):
    print(f"Iterasi ke-{i+1}:")
    print(f"  Jumlah Data Latih: {len(train_index)} baris (Indeks {train_index[0]} s/d {train_index[-1]})")
    print(f"  Jumlah Data Validasi: {len(val_index)} baris (Indeks {val_index[0]} s/d {val_index[-1]})")
    print("-" * 30)
# Out:
# Total baris di X_train: 456
# ------------------------------
# Iterasi ke-1:
#   Jumlah Data Latih: 76 baris (Indeks 0 s/d 75)
#   Jumlah Data Validasi: 76 baris (Indeks 76 s/d 151)
# ------------------------------
# Iterasi ke-2:
#   Jumlah Data Latih: 152 baris (Indeks 0 s/d 151)
#   Jumlah Data Validasi: 76 baris (Indeks 152 s/d 227)
# ------------------------------
# Iterasi ke-3:
#   Jumlah Data Latih: 228 baris (Indeks 0 s/d 227)
#   Jumlah Data Validasi: 76 baris (Indeks 228 s/d 303)
# ------------------------------
# Iterasi ke-4:
#   Jumlah Data Latih: 304 baris (Indeks 0 s/d 303)
#   Jumlah Data Validasi: 76 baris (Indeks 304 s/d 379)
# ------------------------------
# Iterasi ke-5:
#   Jumlah Data Latih: 380 baris (Indeks 0 s/d 379)
#   Jumlah Data Validasi: 76 baris (Indeks 380 s/d 455)
# ------------------------------

# %%
df_check[['id_pasien', 'tgl_pemeriksaan', 'hb_now', 'hemoglobin', 'set']].iloc[
    len(X_train)-5 : len(X_train)+5
]
# Out:
#      id_pasien tgl_pemeriksaan  hb_now  hemoglobin    set
# 451         39      2025-11-01    7.40        6.70  train
# 452         40      2025-11-01    8.90        7.15  train
# 453         41      2025-11-01    6.10        6.90  train
# 454         42      2025-11-01    9.00        8.40  train
# 455         46      2025-11-01    8.50        7.50  train
# 456         47      2025-11-01    7.90        8.20   test
# 457         49      2025-11-01    6.25        6.90   test
# 458         50      2025-11-01    6.60        6.20   test
# 459         52      2025-11-01    8.30        8.10   test
# 460         53      2025-11-01    8.60        7.00   test

# %%
import optuna
from sklearn.model_selection import cross_val_score, TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVR

# --- FUNGSI OBJECTIVE UNTUK MASING-MASING MODEL ---

def obj_svr(trial):
    # Parameter SVR (C dan Epsilon sangat krusial di sini)
    c = trial.suggest_float('C', 0.1, 100.0, log=True)
    epsilon = trial.suggest_float('epsilon', 0.01, 1.0, log=True)
    
    # SVR WAJIB Scaling (StandardScaler)
    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('model', SVR(C=c, epsilon=epsilon))
    ])
    score = cross_val_score(pipe, X_train, y_train, cv=tscv, scoring='neg_mean_absolute_error')
    return -score.mean()

def obj_rf(trial):
    n_est = trial.suggest_int('n_estimators', 50, 300)
    depth = trial.suggest_int('max_depth', 3, 15)
    model = RandomForestRegressor(n_estimators=n_est, max_depth=depth, random_state=42)
    # RF tidak wajib scaling karena berbasis pohon
    score = cross_val_score(model, X_train, y_train, cv=tscv, scoring='neg_mean_absolute_error')
    return -score.mean()

def obj_lgbm(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'verbose': -1
    }
    model = LGBMRegressor(**param, random_state=42)
    score = cross_val_score(model, X_train, y_train, cv=tscv, scoring='neg_mean_absolute_error')
    return -score.mean()

def obj_xgb(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 10)
    }
    model = XGBRegressor(**param, random_state=42)
    score = cross_val_score(model, X_train, y_train, cv=tscv, scoring='neg_mean_absolute_error')
    return -score.mean()

# --- EKSEKUSI TUNING (Bisa memakan waktu beberapa menit) ---

print("Menjalankan Tuning SVR...")
study_svr = optuna.create_study(direction='minimize')
study_svr.optimize(obj_svr, n_trials=30)

print("Menjalankan Tuning Random Forest...")
study_rf = optuna.create_study(direction='minimize')
study_rf.optimize(obj_rf, n_trials=30)

print("Menjalankan Tuning LightGBM...")
study_lgbm = optuna.create_study(direction='minimize')
study_lgbm.optimize(obj_lgbm, n_trials=30)

print("Menjalankan Tuning XGBoost...")
study_xgb = optuna.create_study(direction='minimize')
study_xgb.optimize(obj_xgb, n_trials=30)

print("\n--- TUNING SELESAI ---")
print(f"SVR MAE: {-study_svr.best_value:.4f}")
print(f"RF MAE: {-study_rf.best_value:.4f}")
print(f"LGBM MAE: {-study_lgbm.best_value:.4f}")
print(f"XGB MAE: {-study_xgb.best_value:.4f}")
# Out:
# [I 2026-02-05 00:11:40,906] A new study created in memory with name: no-name-2cfc6af7-4b70-4fa7-91b1-a6f7fb05ae6a
# Menjalankan Tuning SVR...
# [I 2026-02-05 00:11:41,339] Trial 0 finished with value: 0.8030019328600329 and parameters: {'C': 31.378271590607863, 'epsilon': 0.0891542805459877}. Best is trial 0 with value: 0.8030019328600329.
# [I 2026-02-05 00:11:41,488] Trial 1 finished with value: 0.6668779716534728 and parameters: {'C': 0.6681316265014525, 'epsilon': 0.02813076064860852}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:41,636] Trial 2 finished with value: 0.6918954264290572 and parameters: {'C': 3.9191496109293844, 'epsilon': 0.08971824395480109}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:41,846] Trial 3 finished with value: 0.7528013205577773 and parameters: {'C': 22.4832884222223, 'epsilon': 0.2791425788102094}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:42,022] Trial 4 finished with value: 0.6819665734745155 and parameters: {'C': 2.947041508893749, 'epsilon': 0.08241072772255462}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:42,217] Trial 5 finished with value: 0.7447035688085591 and parameters: {'C': 11.333805825337565, 'epsilon': 0.08815217306176631}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:42,376] Trial 6 finished with value: 0.6707841638098875 and parameters: {'C': 1.7194579335650633, 'epsilon': 0.012093254432091903}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:42,496] Trial 7 finished with value: 0.7309589785563859 and parameters: {'C': 0.12162214822503861, 'epsilon': 0.2866841764733822}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:42,637] Trial 8 finished with value: 0.7282915333097753 and parameters: {'C': 0.11552482177955962, 'epsilon': 0.04874221899855055}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:42,754] Trial 9 finished with value: 0.6996717645856869 and parameters: {'C': 3.892789974813895, 'epsilon': 0.9681310798770256}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:42,915] Trial 10 finished with value: 0.6677548505858086 and parameters: {'C': 0.6839666152399685, 'epsilon': 0.013202936481049588}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:43,072] Trial 11 finished with value: 0.6694105893886821 and parameters: {'C': 0.5914609805082057, 'epsilon': 0.01133170468006829}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:43,231] Trial 12 finished with value: 0.672439772534919 and parameters: {'C': 0.4779289413964537, 'epsilon': 0.027768682549809243}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:43,392] Trial 13 finished with value: 0.6672359786526549 and parameters: {'C': 0.6591392781313117, 'epsilon': 0.024008797896871145}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:43,551] Trial 14 finished with value: 0.6859670109239069 and parameters: {'C': 0.2679552138808717, 'epsilon': 0.028132890877353496}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:43,739] Trial 15 finished with value: 0.6669543324874165 and parameters: {'C': 1.2443870631325324, 'epsilon': 0.02845472595898884}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:44,094] Trial 16 finished with value: 0.907135728835651 and parameters: {'C': 73.5369314577036, 'epsilon': 0.04027054245725882}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:44,230] Trial 17 finished with value: 0.6678903152316465 and parameters: {'C': 1.4119523984138627, 'epsilon': 0.020423208627645063}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:44,391] Trial 18 finished with value: 0.6759802619719921 and parameters: {'C': 0.32557271629153856, 'epsilon': 0.1783175904515001}. Best is trial 1 with value: 0.6668779716534728.
# [I 2026-02-05 00:11:44,534] Trial 19 finished with value: 0.6651366704364711 and parameters: {'C': 1.356536870176457, 'epsilon': 0.04784652309352314}. Best is trial 19 with value: 0.6651366704364711.
# [I 2026-02-05 00:11:44,700] Trial 20 finished with value: 0.7330929989166703 and parameters: {'C': 8.89009114181612, 'epsilon': 0.04528237577771482}. Best is trial 19 with value: 0.6651366704364711.
# [I 2026-02-05 00:11:44,823] Trial 21 finished with value: 0.6650040093054808 and parameters: {'C': 1.4529260181503227, 'epsilon': 0.05070265404454989}. Best is trial 21 with value: 0.6650040093054808.
# [I 2026-02-05 00:11:44,999] Trial 22 finished with value: 0.6663675929551431 and parameters: {'C': 1.8349073581018565, 'epsilon': 0.049902312668605314}. Best is trial 21 with value: 0.6650040093054808.
# [I 2026-02-05 00:11:45,167] Trial 23 finished with value: 0.6727484747200612 and parameters: {'C': 2.3539822562492554, 'epsilon': 0.14565691363868105}. Best is trial 21 with value: 0.6650040093054808.
# [I 2026-02-05 00:11:45,338] Trial 24 finished with value: 0.7159944335966875 and parameters: {'C': 6.515619096096466, 'epsilon': 0.049527018256168835}. Best is trial 21 with value: 0.6650040093054808.
# [I 2026-02-05 00:11:45,490] Trial 25 finished with value: 0.6638062200401085 and parameters: {'C': 1.1363495857094805, 'epsilon': 0.06509070149534864}. Best is trial 25 with value: 0.6638062200401085.
# [I 2026-02-05 00:11:45,612] Trial 26 finished with value: 0.6579969406373323 and parameters: {'C': 0.9266044817643158, 'epsilon': 0.14827296761518954}. Best is trial 26 with value: 0.6579969406373323.
# [I 2026-02-05 00:11:45,725] Trial 27 finished with value: 0.695528674467297 and parameters: {'C': 0.20762884623517894, 'epsilon': 0.1558300771969639}. Best is trial 26 with value: 0.6579969406373323.
# [I 2026-02-05 00:11:45,841] Trial 28 finished with value: 0.6660509703451873 and parameters: {'C': 1.0000300499760932, 'epsilon': 0.4569172892566173}. Best is trial 26 with value: 0.6579969406373323.
# [I 2026-02-05 00:11:46,007] Trial 29 finished with value: 0.7050933085342691 and parameters: {'C': 5.223244332820116, 'epsilon': 0.07418331879812928}. Best is trial 26 with value: 0.6579969406373323.
# [I 2026-02-05 00:11:46,008] A new study created in memory with name: no-name-2c0441df-ea98-40ea-ba87-2fe3e11b5174
# Menjalankan Tuning Random Forest...
# [I 2026-02-05 00:11:47,174] Trial 0 finished with value: 0.6652211909136737 and parameters: {'n_estimators': 69, 'max_depth': 3}. Best is trial 0 with value: 0.6652211909136737.
# [I 2026-02-05 00:11:52,587] Trial 1 finished with value: 0.6767365353421788 and parameters: {'n_estimators': 270, 'max_depth': 15}. Best is trial 0 with value: 0.6652211909136737.
# [I 2026-02-05 00:11:54,523] Trial 2 finished with value: 0.6657394878398811 and parameters: {'n_estimators': 176, 'max_depth': 4}. Best is trial 0 with value: 0.6652211909136737.
# [I 2026-02-05 00:11:58,012] Trial 3 finished with value: 0.6758261567782293 and parameters: {'n_estimators': 271, 'max_depth': 13}. Best is trial 0 with value: 0.6652211909136737.
# [I 2026-02-05 00:11:59,586] Trial 4 finished with value: 0.674468155076047 and parameters: {'n_estimators': 95, 'max_depth': 6}. Best is trial 0 with value: 0.6652211909136737.
# [I 2026-02-05 00:12:03,148] Trial 5 finished with value: 0.675229771941542 and parameters: {'n_estimators': 228, 'max_depth': 13}. Best is trial 0 with value: 0.6652211909136737.
# [I 2026-02-05 00:12:05,075] Trial 6 finished with value: 0.6781751454044166 and parameters: {'n_estimators': 151, 'max_depth': 11}. Best is trial 0 with value: 0.6652211909136737.
# [I 2026-02-05 00:12:06,629] Trial 7 finished with value: 0.6683506764763958 and parameters: {'n_estimators': 165, 'max_depth': 5}. Best is trial 0 with value: 0.6652211909136737.
# [I 2026-02-05 00:12:09,466] Trial 8 finished with value: 0.6728835852862093 and parameters: {'n_estimators': 229, 'max_depth': 6}. Best is trial 0 with value: 0.6652211909136737.
# [I 2026-02-05 00:12:10,739] Trial 9 finished with value: 0.6746438702533818 and parameters: {'n_estimators': 114, 'max_depth': 8}. Best is trial 0 with value: 0.6652211909136737.
# [I 2026-02-05 00:12:11,329] Trial 10 finished with value: 0.6645682249025631 and parameters: {'n_estimators': 57, 'max_depth': 3}. Best is trial 10 with value: 0.6645682249025631.
# [I 2026-02-05 00:12:12,238] Trial 11 finished with value: 0.6655948963299709 and parameters: {'n_estimators': 70, 'max_depth': 3}. Best is trial 10 with value: 0.6645682249025631.
# [I 2026-02-05 00:12:12,916] Trial 12 finished with value: 0.6796185834100097 and parameters: {'n_estimators': 53, 'max_depth': 8}. Best is trial 10 with value: 0.6645682249025631.
# [I 2026-02-05 00:12:13,920] Trial 13 finished with value: 0.66348989590684 and parameters: {'n_estimators': 114, 'max_depth': 3}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:15,007] Trial 14 finished with value: 0.6752565652863646 and parameters: {'n_estimators': 124, 'max_depth': 6}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:16,013] Trial 15 finished with value: 0.6786668309578068 and parameters: {'n_estimators': 97, 'max_depth': 10}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:17,260] Trial 16 finished with value: 0.6656822570510574 and parameters: {'n_estimators': 140, 'max_depth': 3}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:19,191] Trial 17 finished with value: 0.6683972307104199 and parameters: {'n_estimators': 199, 'max_depth': 5}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:20,030] Trial 18 finished with value: 0.6774562871848459 and parameters: {'n_estimators': 88, 'max_depth': 8}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:20,468] Trial 19 finished with value: 0.670595323384955 and parameters: {'n_estimators': 52, 'max_depth': 5}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:22,046] Trial 20 finished with value: 0.6753712238056963 and parameters: {'n_estimators': 116, 'max_depth': 7}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:22,807] Trial 21 finished with value: 0.6653461219798988 and parameters: {'n_estimators': 71, 'max_depth': 3}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:23,690] Trial 22 finished with value: 0.6676006731302657 and parameters: {'n_estimators': 78, 'max_depth': 4}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:24,174] Trial 23 finished with value: 0.6652247737060156 and parameters: {'n_estimators': 51, 'max_depth': 4}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:25,111] Trial 24 finished with value: 0.6643199437134564 and parameters: {'n_estimators': 106, 'max_depth': 3}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:26,079] Trial 25 finished with value: 0.6678739855485805 and parameters: {'n_estimators': 134, 'max_depth': 4}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:27,493] Trial 26 finished with value: 0.6690709442449622 and parameters: {'n_estimators': 109, 'max_depth': 5}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:29,303] Trial 27 finished with value: 0.6639294571591857 and parameters: {'n_estimators': 179, 'max_depth': 3}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:31,314] Trial 28 finished with value: 0.6752268215606534 and parameters: {'n_estimators': 186, 'max_depth': 7}. Best is trial 13 with value: 0.66348989590684.
# [I 2026-02-05 00:12:33,413] Trial 29 finished with value: 0.6633727266546462 and parameters: {'n_estimators': 212, 'max_depth': 3}. Best is trial 29 with value: 0.6633727266546462.
# [I 2026-02-05 00:12:33,414] A new study created in memory with name: no-name-0f582ba6-1941-46a7-b303-b31c8cb0dfc0
# Menjalankan Tuning LightGBM...
# [I 2026-02-05 00:12:37,887] Trial 0 finished with value: 0.695717874155897 and parameters: {'n_estimators': 267, 'learning_rate': 0.01690577724914156, 'max_depth': 5, 'num_leaves': 51}. Best is trial 0 with value: 0.695717874155897.
# [I 2026-02-05 00:12:38,185] Trial 1 finished with value: 0.6858774422837781 and parameters: {'n_estimators': 254, 'learning_rate': 0.01583485111782879, 'max_depth': 3, 'num_leaves': 27}. Best is trial 1 with value: 0.6858774422837781.
# [I 2026-02-05 00:12:38,354] Trial 2 finished with value: 0.7022994656620181 and parameters: {'n_estimators': 181, 'learning_rate': 0.005245433280664591, 'max_depth': 3, 'num_leaves': 76}. Best is trial 1 with value: 0.6858774422837781.
# [I 2026-02-05 00:12:38,616] Trial 3 finished with value: 0.6878222997343262 and parameters: {'n_estimators': 238, 'learning_rate': 0.013210716864384507, 'max_depth': 10, 'num_leaves': 76}. Best is trial 1 with value: 0.6858774422837781.
# [I 2026-02-05 00:12:38,776] Trial 4 finished with value: 0.7195533796964204 and parameters: {'n_estimators': 118, 'learning_rate': 0.006202099961786765, 'max_depth': 10, 'num_leaves': 49}. Best is trial 1 with value: 0.6858774422837781.
# [I 2026-02-05 00:12:38,934] Trial 5 finished with value: 0.6991163822329618 and parameters: {'n_estimators': 113, 'learning_rate': 0.010652168475621095, 'max_depth': 10, 'num_leaves': 56}. Best is trial 1 with value: 0.6858774422837781.
# [I 2026-02-05 00:12:39,191] Trial 6 finished with value: 0.701371759645794 and parameters: {'n_estimators': 267, 'learning_rate': 0.04169063983067978, 'max_depth': 4, 'num_leaves': 59}. Best is trial 1 with value: 0.6858774422837781.
# [I 2026-02-05 00:12:39,499] Trial 7 finished with value: 0.721222869292036 and parameters: {'n_estimators': 296, 'learning_rate': 0.07661676252187045, 'max_depth': 3, 'num_leaves': 96}. Best is trial 1 with value: 0.6858774422837781.
# [I 2026-02-05 00:12:39,634] Trial 8 finished with value: 0.6803304146850749 and parameters: {'n_estimators': 97, 'learning_rate': 0.026064940119349404, 'max_depth': 3, 'num_leaves': 22}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:39,856] Trial 9 finished with value: 0.7048002303573593 and parameters: {'n_estimators': 148, 'learning_rate': 0.006738371735968692, 'max_depth': 4, 'num_leaves': 36}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:40,013] Trial 10 finished with value: 0.6937153466823283 and parameters: {'n_estimators': 56, 'learning_rate': 0.034568359283166775, 'max_depth': 7, 'num_leaves': 20}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:40,294] Trial 11 finished with value: 0.6924439860784082 and parameters: {'n_estimators': 184, 'learning_rate': 0.025347061657841178, 'max_depth': 6, 'num_leaves': 22}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:40,448] Trial 12 finished with value: 0.6974486313441715 and parameters: {'n_estimators': 61, 'learning_rate': 0.022111881304079654, 'max_depth': 8, 'num_leaves': 35}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:40,732] Trial 13 finished with value: 0.7033698494311358 and parameters: {'n_estimators': 204, 'learning_rate': 0.057860775557475846, 'max_depth': 5, 'num_leaves': 33}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:40,856] Trial 14 finished with value: 0.6995214830528447 and parameters: {'n_estimators': 102, 'learning_rate': 0.009865803395751155, 'max_depth': 3, 'num_leaves': 41}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:41,015] Trial 15 finished with value: 0.6900385634456343 and parameters: {'n_estimators': 150, 'learning_rate': 0.026289309921162508, 'max_depth': 4, 'num_leaves': 25}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:41,252] Trial 16 finished with value: 0.6899230361831025 and parameters: {'n_estimators': 219, 'learning_rate': 0.016086584777053464, 'max_depth': 8, 'num_leaves': 76}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:41,386] Trial 17 finished with value: 0.6887108846075705 and parameters: {'n_estimators': 83, 'learning_rate': 0.03884004477623013, 'max_depth': 5, 'num_leaves': 29}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:41,561] Trial 18 finished with value: 0.6985951856130723 and parameters: {'n_estimators': 144, 'learning_rate': 0.008690637612505053, 'max_depth': 6, 'num_leaves': 43}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:41,762] Trial 19 finished with value: 0.6874629657976412 and parameters: {'n_estimators': 240, 'learning_rate': 0.017262392480423158, 'max_depth': 3, 'num_leaves': 67}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:42,031] Trial 20 finished with value: 0.7223600196896294 and parameters: {'n_estimators': 299, 'learning_rate': 0.09895868003405343, 'max_depth': 4, 'num_leaves': 92}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:42,233] Trial 21 finished with value: 0.6866142484368484 and parameters: {'n_estimators': 250, 'learning_rate': 0.016670565751889282, 'max_depth': 3, 'num_leaves': 65}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:42,449] Trial 22 finished with value: 0.6900635429379091 and parameters: {'n_estimators': 259, 'learning_rate': 0.021026496440754616, 'max_depth': 3, 'num_leaves': 68}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:42,651] Trial 23 finished with value: 0.6875041020435526 and parameters: {'n_estimators': 211, 'learning_rate': 0.012732403295065873, 'max_depth': 4, 'num_leaves': 85}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:42,947] Trial 24 finished with value: 0.7002532229529889 and parameters: {'n_estimators': 238, 'learning_rate': 0.030819358417183817, 'max_depth': 5, 'num_leaves': 45}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:43,167] Trial 25 finished with value: 0.7046068238307852 and parameters: {'n_estimators': 273, 'learning_rate': 0.04964024505590789, 'max_depth': 3, 'num_leaves': 67}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:43,345] Trial 26 finished with value: 0.6890733177241481 and parameters: {'n_estimators': 159, 'learning_rate': 0.013437575575894162, 'max_depth': 4, 'num_leaves': 30}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:43,522] Trial 27 finished with value: 0.685121694784123 and parameters: {'n_estimators': 198, 'learning_rate': 0.01951544199056985, 'max_depth': 3, 'num_leaves': 27}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:43,728] Trial 28 finished with value: 0.69439211555879 and parameters: {'n_estimators': 189, 'learning_rate': 0.02909521331920812, 'max_depth': 6, 'num_leaves': 27}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:43,896] Trial 29 finished with value: 0.6911438232742143 and parameters: {'n_estimators': 133, 'learning_rate': 0.02108340305117117, 'max_depth': 5, 'num_leaves': 38}. Best is trial 8 with value: 0.6803304146850749.
# [I 2026-02-05 00:12:43,899] A new study created in memory with name: no-name-88a52ee0-8d25-4276-ba65-f61344b7e468
# Menjalankan Tuning XGBoost...
# [I 2026-02-05 00:12:45,998] Trial 0 finished with value: 0.7308228649264127 and parameters: {'n_estimators': 198, 'learning_rate': 0.005457089276286392, 'max_depth': 8}. Best is trial 0 with value: 0.7308228649264127.
# [I 2026-02-05 00:12:46,955] Trial 1 finished with value: 0.7252700133665897 and parameters: {'n_estimators': 164, 'learning_rate': 0.008987220017350646, 'max_depth': 7}. Best is trial 1 with value: 0.7252700133665897.
# [I 2026-02-05 00:12:47,277] Trial 2 finished with value: 0.6828521869650299 and parameters: {'n_estimators': 89, 'learning_rate': 0.0372710295162903, 'max_depth': 4}. Best is trial 2 with value: 0.6828521869650299.
# [I 2026-02-05 00:12:47,846] Trial 3 finished with value: 0.7045128144472599 and parameters: {'n_estimators': 145, 'learning_rate': 0.007671405441855429, 'max_depth': 5}. Best is trial 2 with value: 0.6828521869650299.
# [I 2026-02-05 00:12:48,419] Trial 4 finished with value: 0.6932363966648281 and parameters: {'n_estimators': 104, 'learning_rate': 0.03697595229790722, 'max_depth': 5}. Best is trial 2 with value: 0.6828521869650299.
# [I 2026-02-05 00:12:49,741] Trial 5 finished with value: 0.72852489218035 and parameters: {'n_estimators': 135, 'learning_rate': 0.023452555488210305, 'max_depth': 10}. Best is trial 2 with value: 0.6828521869650299.
# [I 2026-02-05 00:12:50,622] Trial 6 finished with value: 0.7506635928328909 and parameters: {'n_estimators': 106, 'learning_rate': 0.006417186225759781, 'max_depth': 9}. Best is trial 2 with value: 0.6828521869650299.
# [I 2026-02-05 00:12:51,403] Trial 7 finished with value: 0.7173667362873254 and parameters: {'n_estimators': 223, 'learning_rate': 0.08187803743602545, 'max_depth': 5}. Best is trial 2 with value: 0.6828521869650299.
# [I 2026-02-05 00:12:51,652] Trial 8 finished with value: 0.7546247122671806 and parameters: {'n_estimators': 52, 'learning_rate': 0.01011486726896309, 'max_depth': 5}. Best is trial 2 with value: 0.6828521869650299.
# [I 2026-02-05 00:12:52,299] Trial 9 finished with value: 0.7263522551945713 and parameters: {'n_estimators': 70, 'learning_rate': 0.031662717186101225, 'max_depth': 9}. Best is trial 2 with value: 0.6828521869650299.
# [I 2026-02-05 00:12:52,931] Trial 10 finished with value: 0.7144108334515463 and parameters: {'n_estimators': 296, 'learning_rate': 0.08143913557863809, 'max_depth': 3}. Best is trial 2 with value: 0.6828521869650299.
# [I 2026-02-05 00:12:53,228] Trial 11 finished with value: 0.67926446033855 and parameters: {'n_estimators': 100, 'learning_rate': 0.04080532460131365, 'max_depth': 3}. Best is trial 11 with value: 0.67926446033855.
# [I 2026-02-05 00:12:53,588] Trial 12 finished with value: 0.6846155033370145 and parameters: {'n_estimators': 89, 'learning_rate': 0.04820008248905987, 'max_depth': 3}. Best is trial 11 with value: 0.67926446033855.
# [I 2026-02-05 00:12:53,913] Trial 13 finished with value: 0.6662982138172862 and parameters: {'n_estimators': 121, 'learning_rate': 0.01536006689142965, 'max_depth': 3}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:12:54,245] Trial 14 finished with value: 0.6664472723600395 and parameters: {'n_estimators': 128, 'learning_rate': 0.015271001262169202, 'max_depth': 3}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:12:54,856] Trial 15 finished with value: 0.6767390703493328 and parameters: {'n_estimators': 204, 'learning_rate': 0.014184185125044704, 'max_depth': 4}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:12:56,186] Trial 16 finished with value: 0.7179223082115016 and parameters: {'n_estimators': 254, 'learning_rate': 0.016043943852392703, 'max_depth': 6}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:12:56,600] Trial 17 finished with value: 0.6779473777159549 and parameters: {'n_estimators': 129, 'learning_rate': 0.014792536549385645, 'max_depth': 4}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:12:57,758] Trial 18 finished with value: 0.7331688741808684 and parameters: {'n_estimators': 165, 'learning_rate': 0.024212917484128085, 'max_depth': 7}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:12:58,398] Trial 19 finished with value: 0.7082113155657025 and parameters: {'n_estimators': 128, 'learning_rate': 0.011823092531455765, 'max_depth': 6}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:12:58,971] Trial 20 finished with value: 0.6770882094290458 and parameters: {'n_estimators': 188, 'learning_rate': 0.018551913866462547, 'max_depth': 3}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:12:59,623] Trial 21 finished with value: 0.6755135514200019 and parameters: {'n_estimators': 216, 'learning_rate': 0.012493879307487129, 'max_depth': 4}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:13:00,322] Trial 22 finished with value: 0.6777572245940068 and parameters: {'n_estimators': 225, 'learning_rate': 0.011596097403428502, 'max_depth': 4}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:13:00,896] Trial 23 finished with value: 0.6852585553879564 and parameters: {'n_estimators': 257, 'learning_rate': 0.019213748496959678, 'max_depth': 3}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:13:01,367] Trial 24 finished with value: 0.6828807053406274 and parameters: {'n_estimators': 152, 'learning_rate': 0.028076924010488474, 'max_depth': 4}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:13:01,675] Trial 25 finished with value: 0.6755569015226105 and parameters: {'n_estimators': 116, 'learning_rate': 0.012123719920294986, 'max_depth': 3}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:13:02,186] Trial 26 finished with value: 0.679722898442209 and parameters: {'n_estimators': 182, 'learning_rate': 0.008409456034074106, 'max_depth': 4}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:13:02,982] Trial 27 finished with value: 0.7191458179832837 and parameters: {'n_estimators': 238, 'learning_rate': 0.018124435767636952, 'max_depth': 6}. Best is trial 13 with value: 0.6662982138172862.
# [I 2026-02-05 00:13:03,262] Trial 28 finished with value: 0.6659536103791598 and parameters: {'n_estimators': 158, 'learning_rate': 0.013190171134955556, 'max_depth': 3}. Best is trial 28 with value: 0.6659536103791598.
# [I 2026-02-05 00:13:03,569] Trial 29 finished with value: 0.7011245150406394 and parameters: {'n_estimators': 168, 'learning_rate': 0.005184175679749773, 'max_depth': 3}. Best is trial 28 with value: 0.6659536103791598.
# --- TUNING SELESAI ---
# SVR MAE: -0.6580
# RF MAE: -0.6634
# LGBM MAE: -0.6803
# XGB MAE: -0.6660

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd
import numpy as np

# 1. Inisialisasi Model Final dengan Best Parameters dari Optuna
models_final = {
    "Linear Regression (Baseline)": LinearRegression(),
    "SVR": Pipeline([
        ('scaler', StandardScaler()),
        ('model', SVR(**study_svr.best_params))
    ]),
    "Random Forest": RandomForestRegressor(**study_rf.best_params, random_state=42),
    "LightGBM": LGBMRegressor(**study_lgbm.best_params, random_state=42, verbose=-1),
    "XGBoost": XGBRegressor(**study_xgb.best_params, random_state=42)
}

# 2. Proses Training Final & Evaluasi di Data Test (20%)
final_results = []

for name, model in models_final.items():
    # Training menggunakan 80% data
    model.fit(X_train, y_train)
    
    # Prediksi menggunakan 20% data uji
    y_pred = model.predict(X_test)
    
    # Perhitungan Metrik Evaluasi
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    final_results.append({
        "Model": name,
        "MAE": mae,
        "RMSE": rmse,
        "R2": r2
    })

# 3. Menampilkan Tabel Perbandingan Akhir
df_final = pd.DataFrame(final_results).sort_values(by="MAE")
print(df_final)
# Out:
#                           Model       MAE      RMSE        R2
# 1                           SVR  0.586881  0.769638  0.468928
# 3                      LightGBM  0.637461  0.816735  0.401942
# 0  Linear Regression (Baseline)  0.638546  0.789638  0.440969
# 2                 Random Forest  0.651614  0.815175  0.404225
# 4                       XGBoost  0.651787  0.824313  0.390793

# %%
from sklearn.inspection import permutation_importance

# Analisis untuk SVR
result = permutation_importance(models_final["SVR"], X_test, y_test, n_repeats=10, random_state=42)

importance_svr = pd.DataFrame({
    'Fitur': X_train.columns,
    'Importance_Mean': result.importances_mean
}).sort_values(by='Importance_Mean', ascending=False)

print(importance_svr)
# Out:
#        Fitur  Importance_Mean
# 8     hb_now         0.435953
# 2       MCHC         0.070664
# 7        epo         0.064215
# 1         jk         0.062081
# 4        MCV         0.061514
# 6  trombosit         0.046443
# 5   leukosit         0.042322
# 0       usia         0.039836
# 3        MCH         0.027223
